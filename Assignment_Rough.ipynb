# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Energy Dataset

# %%
Energy = pd.read_excel('assets/Energy Indicators.xls', header=None, skipfooter=1)

# %%
Energy.head()
# Out:
#     0    1                                                  2    3    4    5
# 0 NaN  NaN                                                NaN  NaN  NaN  NaN
# 1 NaN  NaN                   Environmental Indicators: Energy  NaN  NaN  NaN
# 2 NaN  NaN                                                NaN  NaN  NaN  NaN
# 3 NaN  NaN  Energy Supply and Renewable Electricity Produc...  NaN  NaN  NaN
# 4 NaN  NaN                                                NaN  NaN  NaN  NaN

# %%
Energy.tail()
# Out:
#       0                                                  1    2    3    4    5
# 277 NaN  Renewable electricity production (%) refers to...  NaN  NaN  NaN  NaN
# 278 NaN                       … denotes no data available.  NaN  NaN  NaN  NaN
# 279 NaN                                                NaN  NaN  NaN  NaN  NaN
# 280 NaN                                     Data Quality:   NaN  NaN  NaN  NaN
# 281 NaN  The data are compiled primarily from the annua...  NaN  NaN  NaN  NaN

# %%
Energy.iloc[18:245, :]
# Out:
#       0                          1                          2     3    4  \
# 18  NaN                Afghanistan                Afghanistan   321   10
# 19  NaN                    Albania                    Albania   102   35
# 20  NaN                    Algeria                    Algeria  1959   51
# 21  NaN             American Samoa             American Samoa   ...  ...
# 22  NaN                    Andorra                    Andorra     9  121
# ..   ..                        ...                        ...   ...  ...
# 240 NaN                   Viet Nam                   Viet Nam  2554   28
# 241 NaN  Wallis and Futuna Islands  Wallis and Futuna Islands     0   26
# 242 NaN                      Yemen                      Yemen   344   13
# 243 NaN                     Zambia                     Zambia   400   26
# 244 NaN                   Zimbabwe                   Zimbabwe   480   32
#
#             5
# 18    78.6693
# 19        100
# 20    0.55101
# 21   0.641026
# ...

# %%
Energy = Energy.iloc[18:245, :]

# %%
Energy.columns.values
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
Energy.drop([0, 1], axis=1, inplace=True)

# %%
Energy.head()
# Out:
#                  2     3    4         5
# 18     Afghanistan   321   10   78.6693
# 19         Albania   102   35       100
# 20         Algeria  1959   51   0.55101
# 21  American Samoa   ...  ...  0.641026
# 22         Andorra     9  121   88.6957

# %%
Energy.rename({2: 'Country', 3: 'Energy_Supply', 4: 'Energy_Supply_Per_Capita', 5: 'Renewable_%'}, axis=1, inplace=True)

# %%
Energy.head()
# Out:
#            Country Energy_Supply Energy_Supply_Per_Capita Renewable_%
# 18     Afghanistan           321                       10     78.6693
# 19         Albania           102                       35         100
# 20         Algeria          1959                       51     0.55101
# 21  American Samoa           ...                      ...    0.641026
# 22         Andorra             9                      121     88.6957

# %%
Energy.isna().sum()
# Out:
# Country                     0
# Energy_Supply               0
# Energy_Supply_Per_Capita    0
# Renewable_%                 0
# dtype: int64

# %%
Energy.dtypes
# Out:
# Country                     object
# Energy_Supply               object
# Energy_Supply_Per_Capita    object
# Renewable_%                 object
# dtype: object

# %%
Energy['Energy_Supply'] = Energy['Energy_Supply'].apply(lambda x: np.nan if x == '...' else x)
Energy['Energy_Supply_Per_Capita'] = Energy['Energy_Supply_Per_Capita'].apply(lambda x: np.nan if x=='...' else x)

# %%
Energy['Energy_Supply'][61]
# Out:
# 585.0

# %%
Energy['Energy_Supply'] = Energy["Energy_Supply"].astype(np.float)
Energy['Energy_Supply_Per_Capita'] = Energy['Energy_Supply_Per_Capita'].astype(np.float)

# %%
Energy['Renewable_%'] = Energy['Renewable_%'].astype(np.float)

# %%
Energy.dtypes
# Out:
# Country                      object
# Energy_Supply               float64
# Energy_Supply_Per_Capita    float64
# Renewable_%                 float64
# dtype: object

# %%
Energy['Energy_Supply'] = Energy['Energy_Supply'].apply(lambda x: x / 1000000)

# %%
Energy.head()
# Out:
#            Country  Energy_Supply  Energy_Supply_Per_Capita  Renewable_%
# 18     Afghanistan       0.000321                      10.0    78.669280
# 19         Albania       0.000102                      35.0   100.000000
# 20         Algeria       0.001959                      51.0     0.551010
# 21  American Samoa            NaN                       NaN     0.641026
# 22         Andorra       0.000009                     121.0    88.695650

# %%
Energy.iloc[44, :]
# Out:
# Country                     China, Macao Special Administrative Region4
# Energy_Supply                                                   4.7e-05
# Energy_Supply_Per_Capita                                             83
# Renewable_%                                                           0
# Name: 62, dtype: object

# %%
Energy.replace({"Republic of Korea": "South Korea",
"United States of America": "United States",
"United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
"China, Hong Kong Special Administrative Region3": "Hong Kong",
"China, Macao Special Administrative Region4": "Macao"}, inplace=True)

# %%
Energy.iloc[216, :]
# Out:
# Country                     United States
# Energy_Supply                    0.090838
# Energy_Supply_Per_Capita              286
# Renewable_%                        11.571
# Name: 234, dtype: object

# %%
import re

# %%
countryregex = '([a-zA-Z\s\-]+)(?:\(*.*\)*)'

# %%
re.findall(countryregex, "India Purohit99")[0]
# Out:
# 'India Purohit'

# %%
Energy['Country'] = Energy['Country'].apply(lambda x: re.findall(countryregex, x)[0].strip())

# %%
Energy['Country']
# Out:
# 18                   Afghanistan
# 19                       Albania
# 20                       Algeria
# 21                American Samoa
# 22                       Andorra
#                  ...
# 240                     Viet Nam
# 241    Wallis and Futuna Islands
# 242                        Yemen
# 243                       Zambia
# 244                     Zimbabwe
# Name: Country, Length: 227, dtype: object

# %%
Energy.shape
# Out:
# (227, 4)

# %%
Energy.tail(30)
# Out:
#                                        Country  Energy_Supply  \
# 215                                Switzerland       0.001113
# 216                       Syrian Arab Republic       0.000542
# 217                                 Tajikistan       0.000106
# 218                                   Thailand       0.005336
# 219  The former Yugoslav Republic of Macedonia       0.000117
# 220                                Timor-Leste       0.000007
# 221                                       Togo       0.000134
# 222                                      Tonga       0.000003
# 223                        Trinidad and Tobago       0.000824
# 224                                    Tunisia       0.000430
# 225                                     Turkey       0.004897
# 226                               Turkmenistan       0.001102
# 227                   Turks and Caicos Islands       0.000003
# 228                                     Tuvalu            NaN
# ...

# %%
Energy['Country'][234]
# Out:
# 'United States'

# %%
Energy[Energy['Country'] == 'United States']
# Out:
#            Country  Energy_Supply  Energy_Supply_Per_Capita  Renewable_%
# 234  United States       0.090838                     286.0     11.57098

# %% [markdown]
# # GDP Dataset

# %%
GDP = pd.read_csv('assets/world_bank.csv', header=None)

# %%
GDP.head()
# Out:
#                   0                             1               2   \
# 0        Data Source  World Development Indicators             NaN
# 1                NaN                           NaN             NaN
# 2  Last Updated Date                    2016-07-22             NaN
# 3                NaN                           NaN             NaN
# 4       Country Name                  Country Code  Indicator Name
#
#                3       4       5       6       7       8       9   ...  \
# 0             NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 1             NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 2             NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 3             NaN     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 4  Indicator Code  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...
#
#        50      51      52      53      54      55      56      57      58  \
# ...

# %%
GDP[0].replace({"Korea, Rep.": "South Korea", 
"Iran, Islamic Rep.": "Iran",
"Hong Kong SAR, China": "Hong Kong"}, inplace=True)

# %%
GDP[0][114]
# Out:
# 'Iran'

# %%
GDP = GDP.iloc[4:, :]

# %%
GDP.shape
# Out:
# (265, 60)

# %%
list(GDP.iloc[0])
# Out:
# ['Country Name',
#  'Country Code',
#  'Indicator Name',
#  'Indicator Code',
#  1960.0,
#  1961.0,
#  1962.0,
#  1963.0,
#  1964.0,
#  1965.0,
#  1966.0,
#  1967.0,
#  1968.0,
#  1969.0,
#  1970.0,
#  1971.0,
#  1972.0,
#  1973.0,
#  1974.0,
#  1975.0,
#  1976.0,
#  1977.0,
#  1978.0,
#  1979.0,
#  1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0]

# %%
column_names_gdp = list(GDP.iloc[0])

# %%
len(column_names_gdp)
# Out:
# 60

# %%
for i in range(4, 60, 1):
    column_names_gdp[i] = str(int(column_names_gdp[i]))

# %%
GDP.columns = column_names_gdp

# %%
GDP.rename({'Country Name': 'Country_Name', 'Country Code': 'Country_Code', 'Indicator Name': 'Indicator_Name'}, axis=1,
          inplace=True)

# %%
GDP.head()
# Out:
#    Country_Name  Country_Code                            Indicator_Name  \
# 4  Country Name  Country Code                            Indicator Name
# 5         Aruba           ABW  GDP at market prices (constant 2010 US$)
# 6       Andorra           AND  GDP at market prices (constant 2010 US$)
# 7   Afghanistan           AFG  GDP at market prices (constant 2010 US$)
# 8        Angola           AGO  GDP at market prices (constant 2010 US$)
#
#    Indicator Code    1960    1961    1962    1963    1964    1965  ...  \
# 4  Indicator Code  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...
# 5  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 6  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 7  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 8  NY.GDP.MKTP.KD     NaN     NaN     NaN     NaN     NaN     NaN  ...
#
#            2006          2007          2008          2009          2010  \
# ...

# %%
GDP = GDP.drop(4, axis=0)

# %%
GDP.head()
# Out:
#   Country_Name Country_Code                            Indicator_Name  \
# 5        Aruba          ABW  GDP at market prices (constant 2010 US$)
# 6      Andorra          AND  GDP at market prices (constant 2010 US$)
# 7  Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 8       Angola          AGO  GDP at market prices (constant 2010 US$)
# 9      Albania          ALB  GDP at market prices (constant 2010 US$)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...          2006  \
# 5  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 6  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  4.018196e+09
# 7  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.030523e+10
# 8  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.581103e+10
# 9  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.771760e+09
#
#            2007          2008          2009          2010          2011  \
# ...

# %%
GDP.shape
# Out:
# (264, 60)

# %%
GDP[GDP['Country_Code'] == 'USA']
# Out:
#       Country_Name Country_Code                            Indicator_Name  \
# 253  United States          USA  GDP at market prices (constant 2010 US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 253  NY.GDP.MKTP.KD  3.078071e+12  3.148867e+12  3.340948e+12  3.487949e+12
#
#              1964          1965  ...          2006          2007  \
# 253  3.690250e+12  3.926426e+12  ...  1.479230e+13  1.505540e+13
#
#              2008          2009          2010          2011          2012  \
# 253  1.501149e+13  1.459484e+13  1.496437e+13  1.520402e+13  1.554216e+13
#
#              2013          2014          2015
# 253  1.577367e+13  1.615662e+13  1.654857e+13
#
# [1 rows x 60 columns]

# %% [markdown]
# # SciEm Dataset

# %%
SciEm = pd.read_excel('assets/scimagojr-3.xlsx')

# %%
SciEm.head()
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
#
#    Self-citations  Citations per document  H index
# 0          411683                    4.70      138
# 1          265436                    8.20      230
# 2           61554                    7.31      134
# 3           37874                    9.84      139
# 4           12422                    1.85       57

# %%
SciEm.sort_values(by='Country')
# Out:
#      Rank         Country  Documents  Citable documents  Citations  \
# 162   163     Afghanistan          3                  3          0
# 117   118         Albania         23                 23        168
# 41     42         Algeria       1215               1197       7393
# 179   180  American Samoa          1                  1          0
# 167   168         Andorra          2                  2         13
# ..    ...             ...        ...                ...        ...
# 47     48       Venezuela        891                886       6109
# 70     71        Viet Nam        261                258       1164
# 111   112           Yemen         28                 28        121
# 122   123          Zambia         19                 19         14
# 118   119        Zimbabwe         22                 21         27
#
#      Self-citations  Citations per document  H index
# 162               0                    0.00        0
# 117              14                    7.30        6
# ...

# %%
SciEm.sort_values(by='Rank')
# Out:
#      Rank             Country  Documents  Citable documents  Citations  \
# 0       1               China     127050             126767     597237
# 1       2       United States      96661              94747     792274
# 2       3               Japan      30504              30287     223024
# 3       4      United Kingdom      20944              20357     206091
# 4       5  Russian Federation      18534              18301      34266
# ..    ...                 ...        ...                ...        ...
# 186   187              Guyana          1                  1          0
# 187   188    Christmas Island          1                  1          0
# 188   189             Reunion          1                  1          2
# 189   190         Saint Lucia          1                  1          0
# 190   191          Mauritania          1                  1          1
#
#      Self-citations  Citations per document  H index
# 0            411683                    4.70      138
# ...

# %% [markdown]
# # Merge

# %%
merged = pd.merge(Energy, GDP, left_on=['Country'], right_on=['Country_Name'])

# %%
merged.head()
# Out:
#           Country  Energy_Supply  Energy_Supply_Per_Capita  Renewable_%  \
# 0     Afghanistan       0.000321                      10.0    78.669280
# 1         Albania       0.000102                      35.0   100.000000
# 2         Algeria       0.001959                      51.0     0.551010
# 3  American Samoa            NaN                       NaN     0.641026
# 4         Andorra       0.000009                     121.0    88.695650
#
#      Country_Name Country_Code                            Indicator_Name  \
# 0     Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 1         Albania          ALB  GDP at market prices (constant 2010 US$)
# 2         Algeria          DZA  GDP at market prices (constant 2010 US$)
# 3  American Samoa          ASM  GDP at market prices (constant 2010 US$)
# 4         Andorra          AND  GDP at market prices (constant 2010 US$)
#
#    Indicator Code          1960          1961  ...          2006  \
# ...

# %%
merged = pd.merge(merged, SciEm, left_on='Country', right_on='Country')

# %%
merged.head()
# Out:
#           Country  Energy_Supply  Energy_Supply_Per_Capita  Renewable_%  \
# 0     Afghanistan       0.000321                      10.0    78.669280
# 1         Albania       0.000102                      35.0   100.000000
# 2         Algeria       0.001959                      51.0     0.551010
# 3  American Samoa            NaN                       NaN     0.641026
# 4         Andorra       0.000009                     121.0    88.695650
#
#      Country_Name Country_Code                            Indicator_Name  \
# 0     Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 1         Albania          ALB  GDP at market prices (constant 2010 US$)
# 2         Algeria          DZA  GDP at market prices (constant 2010 US$)
# 3  American Samoa          ASM  GDP at market prices (constant 2010 US$)
# 4         Andorra          AND  GDP at market prices (constant 2010 US$)
#
#    Indicator Code          1960          1961  ...          2013  \
# ...

# %%
merged.drop(['Country_Name'], axis=1, inplace=True)

# %%
merged.set_index('Country', inplace=True)

# %%
merged.head()
# Out:
#                 Energy_Supply  Energy_Supply_Per_Capita  Renewable_%  \
# Country
# Afghanistan          0.000321                      10.0    78.669280
# Albania              0.000102                      35.0   100.000000
# Algeria              0.001959                      51.0     0.551010
# American Samoa            NaN                       NaN     0.641026
# Andorra              0.000009                     121.0    88.695650
#
#                Country_Code                            Indicator_Name  \
# Country
# Afghanistan             AFG  GDP at market prices (constant 2010 US$)
# Albania                 ALB  GDP at market prices (constant 2010 US$)
# Algeria                 DZA  GDP at market prices (constant 2010 US$)
# American Samoa          ASM  GDP at market prices (constant 2010 US$)
# Andorra                 AND  GDP at market prices (constant 2010 US$)
#
#                 Indicator Code          1960          1961          1962  \
# Country
# ...

# %%
merged.shape
# Out:
# (162, 69)

# %%
final_merged = merged[['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy_Supply', 'Energy_Supply_Per_Capita', 'Renewable_%', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]

# %%
final_merged.head()
# Out:
#                 Rank  Documents  Citable documents  Citations  Self-citations  \
# Country
# Afghanistan      163          3                  3          0               0
# Albania          118         23                 23        168              14
# Algeria           42       1215               1197       7393            1413
# American Samoa   180          1                  1          0               0
# Andorra          168          2                  2         13               0
#
#                 Citations per document  H index  Energy_Supply  \
# Country
# Afghanistan                       0.00        0       0.000321
# Albania                           7.30        6       0.000102
# Algeria                           6.08       40       0.001959
# American Samoa                    0.00        0            NaN
# Andorra                           6.50        1       0.000009
#
#                 Energy_Supply_Per_Capita  Renewable_%          2006  \
# Country
# ...

# %%
final_merged.shape
# Out:
# (162, 20)

# %%
final_merged.sort_values(by='Rank')
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# ...                  ...        ...                ...        ...
# Maldives             183          1                  1          1
# Belize               185          1                  1          6
# Palau                186          1                  1          0
# Guyana               187          1                  1          0
# Mauritania           191          1                  1          1
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                       411683                    4.70      138
# ...

# %%
final_merged.sort_values(by='Rank').iloc[:15, :].shape
# Out:
# (15, 20)

# %%
def get_top15_merged():
    return final_merged.iloc[:15, :]
